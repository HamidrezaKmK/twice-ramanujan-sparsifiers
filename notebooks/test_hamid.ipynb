# %% [markdown]
# # Testing
#
# Let's test the stuff out

# %%
import sys
sys.path.append('..')
# %load_ext autoreload

# %%
# %autoreload 2

from src.TwiceRamanujan import TwiceRamanujan, Clique

# get the laplacian of a clique:
L=Clique(5).laplacian()

# create a TwiceRamanujan object:
TR=TwiceRamanujan(L,d=3)
L_s=TR.sparsify()
print(L_s)
#TR.ellipse()
TR.draw_graph(L_s)
# Out:
# 0:0
# 1:1
# 2:2
# 3:3
# 4:3
# 5:2
# 6:0
# 7:1
# 8:3
# 9:4
# 10:2
# 11:4
# [[192.94767 -44.46715 -37.93713 -57.92146 -52.62192]
#  [-44.46715 106.92568 -62.45853  -0.        0.     ]
#  [-37.93713 -62.45853 100.39566   0.       -0.     ]
#  [-57.92146  -0.        0.       57.92146  -0.     ]
#  [-52.62192   0.       -0.       -0.       52.62192]]
